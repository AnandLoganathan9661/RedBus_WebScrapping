# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options as ChromeOptions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import TimeoutException
import datetime
from decimal import Decimal
import pandas as pd


# Chrome options setup
chrome_options = webdriver.ChromeOptions()


# To disable notifications, geolocation, and media stream
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument('--disable-geolocation')
chrome_options.add_argument('--use-fake-ui-for-media-stream')
chrome_options.add_argument("--enable-features=ReaderMode")

driver=webdriver.Chrome(chrome_options)

# Maximize the browser window
driver.maximize_window()

#Passing the Webiste URL
driver.get("https://www.redbus.in/")

print("\nTitle reads : = "+driver.title)

# try:
element = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH,"//a[text()='View All' and @href='https://www.redbus.in/online-booking/rtc-directory']")))
view_all_element=driver.find_element(By.XPATH,"//a[text()='View All' and @href='https://www.redbus.in/online-booking/rtc-directory']")
view_all_element.click()
time.sleep(5)   

# window_handles[1] is a second window 
driver.switch_to.window(driver.window_handles[1]) 

# prints the title of the second window 
print("\nTitle reads : " + driver.title) 

# xpath of state links
list_of_states = driver.find_elements(By.XPATH, "//a[@class='D113_link']") 

counter=0
Red_bus = []
state_list = []
format_str = "%H:%M"
selected_state_list = ["KSRTC (Kerala)", "APSRTC", "TSRTC", "South Bengal State Transport Corporation (SBSTC)", "West Bengal Transport Corporation","UPSRTC", "HRTC", "Sikkim Nationalised Transport (SNT)", "Meghalaya Transport Corporation(MTC)"]

#Convert String to Time
def convert_string_to_time(local_date):
    format_str = "%H:%M"
    dt = datetime.strptime(local_date, format_str)
    t = dt.time()
    return t

#Convert Rating into float
def convert_rating(local_text):
    if local_text =="New" or local_text =="" or local_text ==" ":            
        result=0.00
    else:
        result= float(local_text.split()[0])   
    return result

# Iterate through all the state
for state in list_of_states:
    if state.text in selected_state_list:
        state_list.append(state)
        counter=counter+1
        print("{}:{}".format(counter,state.text))

for state in state_list:
    driver.implicitly_wait(10)
    state_url=state.get_attribute('href')
    local_state=""
    local_state=state.text
    driver.switch_to.new_window('tab')
    driver.implicitly_wait(10)
    driver.get(state_url)
    print("\nTraversing through {} state routes".format(local_state))

    list_of_routes= driver.find_elements (By.XPATH,"//a[@class='route']")
    
    for route in list_of_routes:
        driver.implicitly_wait(10)
        route_url=""
        route_url=route.get_attribute('href')
        local_route=""
        local_route=route.text
        driver.switch_to.new_window('tab')
        driver.implicitly_wait(10)
        driver.get(route_url)
        print("\nTraversing through {} route's buses".format(local_route))
        
        try:
            # Wait for the bus count element to be present
            bus_count = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CSS_SELECTOR, "span.f-bold.busFound")))
            temp = bus_count.text 
            BusCount = int(temp.split()[0])
            print("Total Bus Count of the {} is {}".format(local_route,BusCount))

            scroll_attempts = 0    
            netCount = BusCount
            max_attempts = int(BusCount/7.5) + 2  
            
            while scroll_attempts < max_attempts:
                driver.execute_script("window.scrollBy(0, 3000);")
                scroll_attempts += 1
                
            time.sleep(3)

            # Get bus details elements       
            list_of_buses= driver.find_elements(By.XPATH,"//li[@class='row-sec clearfix']")

            for bus in list_of_buses:
                js_code3 = "arguments[0].scrollIntoView();"
                driver.execute_script(js_code3, bus)
                # Get bus details elements
                bus_name = bus.find_element(By.CSS_SELECTOR, '.travels').text
                bus_type = bus.find_element(By.CSS_SELECTOR,'.bus-type').text
                departure_time = bus.find_element(By.CSS_SELECTOR, '.dp-time').text
                arrival_time = bus.find_element(By.CSS_SELECTOR, '.bp-time').text
                price = bus.find_element(By.CSS_SELECTOR, '.fare').text
                duration = bus.find_element(By.CSS_SELECTOR, '.dur').text
                star_rating= bus.find_element(By.CSS_SELECTOR,"div[class='column-six p-right-10 w-10 fl']").text
                seats_available=bus.find_element(By.CSS_SELECTOR,'.seat-left').text
            

                #conversion
                converted_departure_time = convert_string_to_time(departure_time)
                converted_arrival_time = convert_string_to_time(arrival_time)
                converted_star_rating= convert_rating(star_rating)
                converted_seats_available=int(seats_available.split()[0])
                converted_price=Decimal(price.split()[-1])
                                

                print('''\nTraversing through {} state route {} and the URL is {}
                \nTravels:{}\tType:{} 
                \n Duration:{}\tDeparture Time:{}\tArrival Time:{}
                \n Seat Available:{}\tPrice:{}\tStar Rating:{}
                '''.format(local_state,local_route,route_url,bus_name,bus_type,duration,converted_departure_time,converted_arrival_time,converted_seats_available,converted_price,converted_star_rating))

                # Append to list
                Red_bus.append({
                    'route_name': local_route,
                    'route_link': route_url,
                    'busname': bus_name,
                    'bustype':bus_type,
                    'departing_time': converted_departure_time,
                    'duration':duration,
                    'reaching_time':converted_arrival_time,
                    'star_rating':converted_star_rating,
                    'price':converted_price,
                    'seats_available':converted_seats_available
                })

      
            driver.close()
            time.sleep(10)
            driver.switch_to.window(driver.window_handles[2])

        except TimeoutException as e:
            print("Temporarily No buses are available on this route")
            driver.close()
            time.sleep(5)
            driver.switch_to.window(driver.window_handles[2])                                   

    driver.close()
    time.sleep(10)
    driver.switch_to.window(driver.window_handles[1])

    

driver.back()
time.sleep(10)
driver.back()
driver.quit()
# Out:
# Title reads : = Bus Ticket Booking Online made Easy, Secure with Top Bus Operators - redBus
#
# Title reads : List of RTC Operators in India, Bus Directory, Top Bus Routes - redbus.in
# 1:West Bengal Transport Corporation
# 2:South Bengal State Transport Corporation (SBSTC)
# 3:HRTC
# 4:UPSRTC
# 5:KSRTC (Kerala)
# 6:TSRTC
# 7:APSRTC
# 8:Sikkim Nationalised Transport (SNT)
# 9:Meghalaya Transport Corporation(MTC)
#
# Traversing through West Bengal Transport Corporation state routes
#
# Traversing through Kolkata to Digha route's buses
# Total Bus Count of the Kolkata to Digha is 256
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Express Line	Type:Volvo 9600 Multi Axle Semi-Sleeper (2+2)
#
#  Duration:04h 25m	Departure Time:07:30:00	Arrival Time:11:55:00
#
#  Seat Available:47	Price:404	Star Rating:4.6
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Express Line	Type:Volvo A/C Seater (2+2)
#
#  Duration:05h 00m	Departure Time:23:45:00	Arrival Time:04:45:00
#
#  Seat Available:45	Price:404	Star Rating:4.5
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Shyamoli Paribahan Pvt Ltd	Type:VE A/C Seater (2+2)
#
#  Duration:05h 00m	Departure Time:23:30:00	Arrival Time:04:30:00
#
#  Seat Available:30	Price:495	Star Rating:4.4
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Shyamoli Paribahan Pvt Ltd	Type:VE A/C Seater (2+2)
#
#  Duration:04h 45m	Departure Time:07:15:00	Arrival Time:12:00:00
#
#  Seat Available:28	Price:428	Star Rating:4.4
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Greenline	Type:Volvo A/C Seater (2+2)
#
#  Duration:05h 00m	Departure Time:06:45:00	Arrival Time:11:45:00
#
#  Seat Available:30	Price:350	Star Rating:4.3
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Snemita Paribahan (Shinjini)	Type:AC Seater (2+2)
#
#  Duration:04h 50m	Departure Time:23:45:00	Arrival Time:04:35:00
#
#  Seat Available:16	Price:320	Star Rating:3.8
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:The Joy Ride	Type:A/C Seater / Sleeper (2+2)
#
#  Duration:05h 00m	Departure Time:02:00:00	Arrival Time:07:00:00
#
#  Seat Available:39	Price:650	Star Rating:3.8
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Santosh Bus Service	Type:A/C Seater Push Back (2+3)
#
#  Duration:05h 09m	Departure Time:11:51:00	Arrival Time:17:00:00
#
#  Seat Available:46	Price:323	Star Rating:4.1
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:City Express (SONAMONI)	Type:AC Seater (2+3)
#
#  Duration:04h 42m	Departure Time:11:28:00	Arrival Time:16:10:00
#
#  Seat Available:21	Price:370	Star Rating:3.5
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Arunita Paribahan	Type:AC Seater (2+2)
#
#  Duration:05h 00m	Departure Time:23:45:00	Arrival Time:04:45:00
#
#  Seat Available:21	Price:370	Star Rating:3.4
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:City Express	Type:AC Seater (2+3)
#
#  Duration:04h 10m	Departure Time:07:00:00	Arrival Time:11:10:00
#
#  Seat Available:31	Price:370	Star Rating:3.7
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Arunita Paribahan	Type:A/C Executive (2+3)
#
#  Duration:04h 30m	Departure Time:09:30:00	Arrival Time:14:00:00
#
#  Seat Available:21	Price:325	Star Rating:3.4
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Sagufta Travels (Kojagor)	Type:A/C Seater Push Back (2+3)
#
#  Duration:04h 50m	Departure Time:17:00:00	Arrival Time:21:50:00
#
#  Seat Available:26	Price:299	Star Rating:3.4
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Jay Baba Bhutnath(Jackson)	Type:A/C Seater (2+3)
#
#  Duration:04h 30m	Departure Time:06:00:00	Arrival Time:10:30:00
#
#  Seat Available:25	Price:300	Star Rating:3.6
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Ankita Paribahan (Satya)	Type:A/C Seater Push Back (2+3)
#
#  Duration:04h 15m	Departure Time:07:20:00	Arrival Time:11:35:00
#
#  Seat Available:21	Price:399	Star Rating:3.6
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Snemita Paribahan	Type:AC Seater (2+3)
#
#  Duration:04h 40m	Departure Time:06:30:00	Arrival Time:11:10:00
#
#  Seat Available:23	Price:370	Star Rating:3.8
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Snemita Paribahan(JACKSON)	Type:A/C Push Back (2+3)
#
#  Duration:04h 25m	Departure Time:06:05:00	Arrival Time:10:30:00
#
#  Seat Available:15	Price:370	Star Rating:3.9
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Adhikary Paribahan	Type:A/C Seater Push Back (2+3)
#
#  Duration:04h 30m	Departure Time:15:00:00	Arrival Time:19:30:00
#
#  Seat Available:16	Price:265	Star Rating:3.8
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Purusottam Travels	Type:A/C Seater (2+3)
#
#  Duration:05h 26m	Departure Time:14:39:00	Arrival Time:20:05:00
#
#  Seat Available:46	Price:305	Star Rating:3.4
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Sagufta Travels(Sonamoni)	Type:A/C Seater Push Back (2+3)
#
#  Duration:05h 00m	Departure Time:11:20:00	Arrival Time:16:20:00
#
#  Seat Available:20	Price:299	Star Rating:3.3
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Santosh Bus Service	Type:A/C Seater Push Back (2+3)
#
#  Duration:05h 15m	Departure Time:15:55:00	Arrival Time:21:10:00
#
#  Seat Available:36	Price:250	Star Rating:3.7
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Snemita Parisheba	Type:AC Seater (2+3)
#
#  Duration:04h 15m	Departure Time:05:20:00	Arrival Time:09:35:00
#
#  Seat Available:31	Price:370	Star Rating:3.7
#
#
# Traversing through West Bengal Transport Corporation state route Kolkata to Digha and the URL is https://www.redbus.in/bus-tickets/kolkata-to-digha
#
# Travels:Ankita Paribahan (Maity Motor)	Type:A/C Seater Push Back (2+3)
#
# ...
#
# Travels:APSARA BUS SERVICE	Type:Non AC Seater (2+2)
#
#  Duration:04h 35m	Departure Time:08:40:00	Arrival Time:13:15:00
#
#  Seat Available:27	Price:500	Star Rating:0.0
#
#
# Traversing through Sikkim Nationalised Transport (SNT) state route Gangtok to Siliguri and the URL is https://www.redbus.in/bus-tickets/gangtok-to-siliguri
#
# Travels:APSARA BUS SERVICE	Type:Non AC Seater (2+2)
#
#  Duration:03h 55m	Departure Time:09:00:00	Arrival Time:12:55:00
#
#  Seat Available:28	Price:500	Star Rating:0.0
#
#
# Traversing through Sikkim Nationalised Transport (SNT) state route Gangtok to Siliguri and the URL is https://www.redbus.in/bus-tickets/gangtok-to-siliguri
#
# Travels:APSARA BUS SERVICE	Type:Non AC Seater (2+2)
#
#  Duration:04h 30m	Departure Time:10:50:00	Arrival Time:15:20:00
#
#  Seat Available:28	Price:500	Star Rating:1.4
#
#
# Traversing through Sikkim Nationalised Transport (SNT) state route Gangtok to Siliguri and the URL is https://www.redbus.in/bus-tickets/gangtok-to-siliguri
#
# Travels:APSARA BUS SERVICE	Type:Non AC Seater (2+2)
#
#  Duration:04h 30m	Departure Time:12:30:00	Arrival Time:17:00:00
#
#  Seat Available:28	Price:500	Star Rating:0.0
#
#
# Traversing through Sikkim Nationalised Transport (SNT) state route Gangtok to Siliguri and the URL is https://www.redbus.in/bus-tickets/gangtok-to-siliguri
#
# Travels:APSARA BUS SERVICE	Type:Non AC Seater (2+2)
#
#  Duration:04h 35m	Departure Time:14:00:00	Arrival Time:18:35:00
#
#  Seat Available:28	Price:500	Star Rating:0.0
#
#
# Traversing through Sikkim Nationalised Transport (SNT) state route Gangtok to Siliguri and the URL is https://www.redbus.in/bus-tickets/gangtok-to-siliguri
#
# Travels:APSARA BUS SERVICE	Type:Non AC Seater (2+2)
#
#  Duration:04h 05m	Departure Time:15:30:00	Arrival Time:19:35:00
#
#  Seat Available:28	Price:500	Star Rating:0.0
#
#
# Traversing through Siliguri to Gangtok route's buses
# Total Bus Count of the Siliguri to Gangtok is 7
#
# Traversing through Sikkim Nationalised Transport (SNT) state route Siliguri to Gangtok and the URL is https://www.redbus.in/bus-tickets/siliguri-to-gangtok
#
# Travels:APSARA BUS SERVICE	Type:Non AC Seater (2+2)
#
#  Duration:03h 55m	Departure Time:05:00:00	Arrival Time:08:55:00
#
#  Seat Available:28	Price:500	Star Rating:0.0
#
#
# Traversing through Sikkim Nationalised Transport (SNT) state route Siliguri to Gangtok and the URL is https://www.redbus.in/bus-tickets/siliguri-to-gangtok
#
# Travels:APSARA BUS SERVICE	Type:Non AC Seater (2+2)
#
#  Duration:03h 55m	Departure Time:06:40:00	Arrival Time:10:35:00
#
#  Seat Available:18	Price:500	Star Rating:0.0
#
#
# Traversing through Sikkim Nationalised Transport (SNT) state route Siliguri to Gangtok and the URL is https://www.redbus.in/bus-tickets/siliguri-to-gangtok
#
# Travels:APSARA BUS SERVICE	Type:Non AC Seater (2+2)
#
#  Duration:03h 55m	Departure Time:07:00:00	Arrival Time:10:55:00
#
#  Seat Available:28	Price:400	Star Rating:0.0
#
#
# Traversing through Sikkim Nationalised Transport (SNT) state route Siliguri to Gangtok and the URL is https://www.redbus.in/bus-tickets/siliguri-to-gangtok
#
# Travels:APSARA BUS SERVICE	Type:Non AC Seater (2+2)
#
#  Duration:03h 55m	Departure Time:08:00:00	Arrival Time:11:55:00
#
#  Seat Available:23	Price:500	Star Rating:1.4
#
#
# Traversing through Sikkim Nationalised Transport (SNT) state route Siliguri to Gangtok and the URL is https://www.redbus.in/bus-tickets/siliguri-to-gangtok
#
# Travels:APSARA BUS SERVICE	Type:Non AC Seater (2+2)
#
#  Duration:04h 00m	Departure Time:09:30:00	Arrival Time:13:30:00
#
#  Seat Available:28	Price:500	Star Rating:0.0
#
#
# Traversing through Sikkim Nationalised Transport (SNT) state route Siliguri to Gangtok and the URL is https://www.redbus.in/bus-tickets/siliguri-to-gangtok
#
# Travels:APSARA BUS SERVICE	Type:Non AC Seater (2+2)
#
#  Duration:04h 00m	Departure Time:11:00:00	Arrival Time:15:00:00
#
#  Seat Available:28	Price:500	Star Rating:0.0
#
#
# Traversing through Sikkim Nationalised Transport (SNT) state route Siliguri to Gangtok and the URL is https://www.redbus.in/bus-tickets/siliguri-to-gangtok
#
# Travels:APSARA BUS SERVICE	Type:Non AC Seater (2+2)
#
#  Duration:04h 05m	Departure Time:14:30:00	Arrival Time:18:35:00
#
#  Seat Available:28	Price:500	Star Rating:0.0
#
#
# Traversing through Siliguri to Rangpo route's buses
# Temporarily No buses are available on this route
#
# Traversing through Rangpo to Siliguri route's buses
# Temporarily No buses are available on this route
#
# Traversing through Siliguri to Pelling (Sikkim) route's buses
# Temporarily No buses are available on this route
#
# Traversing through Pelling (Sikkim) to Siliguri route's buses
# Temporarily No buses are available on this route
#
# Traversing through Ravangla (Sikkim) to Siliguri route's buses
# Total Bus Count of the Ravangla (Sikkim) to Siliguri is 1
#
# Traversing through Sikkim Nationalised Transport (SNT) state route Ravangla (Sikkim) to Siliguri and the URL is https://www.redbus.in/bus-tickets/ravangla-sikkim-to-siliguri
#
# Travels:Sikkim Nationalised Transport (SNT) - 170710	Type:NON A/C Seater (2+2)
#
#  Duration:06h 00m	Departure Time:07:00:00	Arrival Time:13:00:00
#
#  Seat Available:27	Price:280	Star Rating:3.4
#
#
# Traversing through Siliguri to Jorethang (Sikkim) route's buses
# Total Bus Count of the Siliguri to Jorethang (Sikkim) is 1
#
# Traversing through Sikkim Nationalised Transport (SNT) state route Siliguri to Jorethang (Sikkim) and the URL is https://www.redbus.in/bus-tickets/siliguri-to-jorethang-sikkim
#
# Travels:Sikkim Nationalised Transport (SNT) - 170788	Type:NON A/C Seater (2+2)
#
#  Duration:04h 00m	Departure Time:13:30:00	Arrival Time:17:30:00
#
#  Seat Available:26	Price:200	Star Rating:3.0
#
#
# Traversing through Singtham (Sikkim) to Siliguri route's buses
# Temporarily No buses are available on this route
#
# Traversing through Siliguri to Singtham (Sikkim) route's buses
# Temporarily No buses are available on this route
#
# Traversing through Meghalaya Transport Corporation(MTC) state routes
#
# Traversing through Guwahati to Shillong route's buses
# Temporarily No buses are available on this route
#
# Traversing through Shillong to Tura (Meghalaya) route's buses
# Total Bus Count of the Shillong to Tura (Meghalaya) is 2
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Shillong to Tura (Meghalaya) and the URL is https://www.redbus.in/bus-tickets/shillong-to-tura-meghalaya
#
# Travels:Meghalaya Transport Corporation(MTC) - 163306	Type:Tata Non A/C Seater Executive Luxury (2+2)
#
#  Duration:10h 30m	Departure Time:17:00:00	Arrival Time:03:30:00
#
#  Seat Available:27	Price:517	Star Rating:3.3
#
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Shillong to Tura (Meghalaya) and the URL is https://www.redbus.in/bus-tickets/shillong-to-tura-meghalaya
#
# Travels:NETWORK TRAVELS	Type:NON A/C Seater (2+2)
#
#  Duration:13h 30m	Departure Time:17:00:00	Arrival Time:06:30:00
#
#  Seat Available:26	Price:500	Star Rating:4.0
#
#
# Traversing through Shillong to Guwahati route's buses
# Total Bus Count of the Shillong to Guwahati is 4
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Shillong to Guwahati and the URL is https://www.redbus.in/bus-tickets/shillong-to-guwahati
#
# Travels:Upasana Travels (Under ASTC)	Type:Non AC Seater (2+2)
#
#  Duration:04h 00m	Departure Time:07:00:00	Arrival Time:11:00:00
#
#  Seat Available:38	Price:325	Star Rating:3.4
#
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Shillong to Guwahati and the URL is https://www.redbus.in/bus-tickets/shillong-to-guwahati
#
# Travels:RAYAN TRAVELS	Type:Non A/C Seater / Sleeper (2+1)
#
#  Duration:02h 30m	Departure Time:16:00:00	Arrival Time:18:30:00
#
#  Seat Available:50	Price:350	Star Rating:3.3
#
#
# Traversing through Tura (Meghalaya) to Shillong route's buses
# Total Bus Count of the Tura (Meghalaya) to Shillong is 2
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Tura (Meghalaya) to Shillong and the URL is https://www.redbus.in/bus-tickets/tura-meghalaya-to-shillong
#
# Travels:Meghalaya Transport Corporation(MTC) - 163370	Type:Tata Non A/C Seater Executive Luxury (2+2)
#
#  Duration:09h 30m	Departure Time:18:30:00	Arrival Time:04:00:00
#
#  Seat Available:7	Price:517	Star Rating:3.4
#
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Tura (Meghalaya) to Shillong and the URL is https://www.redbus.in/bus-tickets/tura-meghalaya-to-shillong
#
# Travels:NETWORK TRAVELS	Type:NON A/C Seater (2+2)
#
#  Duration:13h 00m	Departure Time:19:00:00	Arrival Time:08:00:00
#
#  Seat Available:31	Price:500	Star Rating:3.4
#
#
# Traversing through Shillong to Silchar route's buses
# Total Bus Count of the Shillong to Silchar is 2
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Shillong to Silchar and the URL is https://www.redbus.in/bus-tickets/shillong-to-silchar
#
# Travels:Meghalaya Transport Corporation(MTC) - 163308	Type:Tata Non A/C Seater Executive Luxury (2+2)
#
#  Duration:09h 45m	Departure Time:19:15:00	Arrival Time:05:00:00
#
#  Seat Available:35	Price:384	Star Rating:2.9
#
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Shillong to Silchar and the URL is https://www.redbus.in/bus-tickets/shillong-to-silchar
#
# Travels:Jagannath Travels and Tours Pvt. Ltd.	Type:NON A/C Seater Push Back (2+1)
#
#  Duration:08h 30m	Departure Time:09:00:00	Arrival Time:17:30:00
#
#  Seat Available:35	Price:700	Star Rating:2.0
#
#
# Traversing through Silchar to Shillong route's buses
# Total Bus Count of the Silchar to Shillong is 4
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Silchar to Shillong and the URL is https://www.redbus.in/bus-tickets/silchar-to-shillong
#
# Travels:Assam State Transport Corporation (ASTC) - 139638	Type:NON A/C Seater Push Back (2+1)
#
#  Duration:10h 15m	Departure Time:16:45:00	Arrival Time:03:00:00
#
#  Seat Available:26	Price:408	Star Rating:2.9
#
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Silchar to Shillong and the URL is https://www.redbus.in/bus-tickets/silchar-to-shillong
#
# Travels:Meghalaya Transport Corporation(MTC) - 170307	Type:Tata Non A/C Seater Executive Luxury (2+2)
#
#  Duration:09h 30m	Departure Time:18:00:00	Arrival Time:03:30:00
#
#  Seat Available:35	Price:384	Star Rating:2.9
#
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Silchar to Shillong and the URL is https://www.redbus.in/bus-tickets/silchar-to-shillong
#
# Travels:Jagannath Travels and Tours Pvt. Ltd.	Type:NON AC Seater / Sleeper 2+1
#
#  Duration:08h 00m	Departure Time:18:30:00	Arrival Time:02:30:00
#
#  Seat Available:46	Price:550	Star Rating:3.8
#
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Silchar to Shillong and the URL is https://www.redbus.in/bus-tickets/silchar-to-shillong
#
# Travels:Jagannath Travels and Tours Pvt. Ltd.	Type:NON A/C Seater Push Back (2+1)
#
#  Duration:08h 30m	Departure Time:18:30:00	Arrival Time:03:00:00
#
#  Seat Available:31	Price:600	Star Rating:2.2
#
#
# Traversing through Shillong to Karimganj route's buses
# Total Bus Count of the Shillong to Karimganj is 4
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Shillong to Karimganj and the URL is https://www.redbus.in/bus-tickets/shillong-to-karimganj
#
# Travels:Meghalaya Transport Corporation(MTC) - 163360	Type:Tata Non A/C Seater Executive Luxury (2+2)
#
#  Duration:09h 15m	Departure Time:19:15:00	Arrival Time:04:30:00
#
#  Seat Available:35	Price:371	Star Rating:3.6
#
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Shillong to Karimganj and the URL is https://www.redbus.in/bus-tickets/shillong-to-karimganj
#
# Travels:NETWORK TRAVELS	Type:NON A/C Seater Push Back (2+1)
#
#  Duration:08h 30m	Departure Time:20:30:00	Arrival Time:05:00:00
#
#  Seat Available:35	Price:650	Star Rating:3.7
#
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Shillong to Karimganj and the URL is https://www.redbus.in/bus-tickets/shillong-to-karimganj
#
# Travels:NETWORK TRAVELS	Type:NON A/C Seater Push Back (2+1)
#
#  Duration:08h 45m	Departure Time:21:35:00	Arrival Time:06:20:00
#
#  Seat Available:35	Price:750	Star Rating:3.7
#
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Shillong to Karimganj and the URL is https://www.redbus.in/bus-tickets/shillong-to-karimganj
#
# Travels:JAYSIKA	Type:NON A/C Seater Push Back (2+1)
#
#  Duration:09h 00m	Departure Time:20:00:00	Arrival Time:05:00:00
#
#  Seat Available:35	Price:700	Star Rating:2.1
#
#
# Traversing through Shillong to Williamnagar (Meghalaya) route's buses
# Total Bus Count of the Shillong to Williamnagar (Meghalaya) is 1
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Shillong to Williamnagar (Meghalaya) and the URL is https://www.redbus.in/bus-tickets/shillong-to-williamnagar-meghalaya
#
# Travels:Meghalaya Transport Corporation(MTC) - 163306	Type:Tata Non A/C Seater Executive Luxury (2+2)
#
#  Duration:12h 00m	Departure Time:17:00:00	Arrival Time:05:00:00
#
#  Seat Available:35	Price:581	Star Rating:3.2
#
#
# Traversing through Karimganj to Shillong route's buses
# Total Bus Count of the Karimganj to Shillong is 1
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Karimganj to Shillong and the URL is https://www.redbus.in/bus-tickets/karimganj-to-shillong
#
# Travels:JAYSIKA	Type:NON A/C Seater Push Back (2+1)
#
#  Duration:09h 40m	Departure Time:17:20:00	Arrival Time:03:00:00
#
#  Seat Available:35	Price:650	Star Rating:2.6
#
#
# Traversing through Williamnagar (Meghalaya) to Shillong route's buses
# Total Bus Count of the Williamnagar (Meghalaya) to Shillong is 1
#
# Traversing through Meghalaya Transport Corporation(MTC) state route Williamnagar (Meghalaya) to Shillong and the URL is https://www.redbus.in/bus-tickets/williamnagar-meghalaya-to-shillong
#
# Travels:Meghalaya Transport Corporation(MTC) - 163370	Type:Tata Non A/C Seater Executive Luxury (2+2)
#
#  Duration:11h 00m	Departure Time:17:00:00	Arrival Time:04:00:00
#
#  Seat Available:7	Price:581	Star Rating:3.0

# %%
# Pushing the list into DataFrame
df = pd.DataFrame(Red_bus)

# Get the current date and time
now = datetime.datetime.now()

# Format the date and time as a string
timestamp = now.strftime("%Y%m%d_%H%M%S")

# Create the filename with the current date and time
filename = f"Red_Bus_{timestamp}.csv"

# Extract file for backup purpose
df.to_csv(filename)

# %%
#Creating a new index column and adding it into Dataframe
df['ID']= range(1,len(df)+1)
df.set_index('ID',inplace=True)

# Print the DataFrame
print(df)

# %%
#MySQL Connection

from sqlalchemy import create_engine, text
import json

def read_config(file_path):
    with open(file_path, 'r') as file:
        config = json.load(file)
    return config

# Reading database connection parameters from Configuration file
config = read_config('config.json')

# Define database connection parameters
username = config.get('username')
password = config.get('password')
host= config.get('host')
port= config.get('port')

database = 'Red_Bus'

# Create SQLAlchemy engine
engine = create_engine(f'mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}')

# %%
#Inserting DataFrame into table, created in MySQL.

# Define the table name
table_name = 'bus_routes'
 

#Truncate the table before inserting 
with engine.connect() as connection:
    sql_query = text("Truncate table bus_routes")
     # Execute the query
    result = connection.execute(sql_query)

#Insert DataFrame into MySQL table
df.to_sql(name=table_name, con=engine, if_exists='replace', index=True)
